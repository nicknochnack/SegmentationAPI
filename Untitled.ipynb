# %%
import requests

url = "https://frozen-savannah-32709.herokuapp.com/"

payload={}
files=[
  ('data',('testimg.jpg',open('testimg.jpg','rb'),'image/jpeg'))
]
headers = {
  'accept': 'application/json'
}

response = requests.request("POST", url, headers=headers, data=payload, files=files)

print(response.text)
# Out:
# <!DOCTYPE html>
# 	<html>
# 	  <head>
# 		<meta name="viewport" content="width=device-width, initial-scale=1">
# 		<meta charset="utf-8">
# 		<title>Application Error</title>
# 		<style media="screen">
# 		  html,body,iframe {
# 			margin: 0;
# 			padding: 0;
# 		  }
# 		  html,body {
# 			height: 100%;
# 			overflow: hidden;
# 		  }
# 		  iframe {
# 			width: 100%;
# 			height: 100%;
# 			border: 0;
# 		  }
# 		</style>
# 	  </head>
# 	  <body>
# 		<iframe src="//www.herokucdn.com/error-pages/application-error.html"></iframe>
# 	  </body>
# 	</html>

# %%
# !pip install opencv-python matplotlib
# Out:
# Collecting opencv-python
#   Using cached opencv_python-4.6.0.66-cp36-abi3-win_amd64.whl (35.6 MB)
# Collecting matplotlib
#   Using cached matplotlib-3.6.1-cp39-cp39-win_amd64.whl (7.2 MB)
# Requirement already satisfied: numpy>=1.17.3 in d:\youtube\12-10-2022 - cancer detection\cancer\lib\site-packages (from opencv-python) (1.23.4)
# Requirement already satisfied: python-dateutil>=2.7 in d:\youtube\12-10-2022 - cancer detection\cancer\lib\site-packages (from matplotlib) (2.8.2)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.37.4-py3-none-any.whl (960 kB)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.0.5-cp39-cp39-win_amd64.whl (161 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\youtube\12-10-2022 - cancer detection\cancer\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in d:\youtube\12-10-2022 - cancer detection\cancer\lib\site-packages (from matplotlib) (21.3)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.4.4-cp39-cp39-win_amd64.whl (55 kB)
# Collecting pillow>=6.2.0
#   Using cached Pillow-9.2.0-cp39-cp39-win_amd64.whl (3.3 MB)
# Requirement already satisfied: six>=1.5 in d:\youtube\12-10-2022 - cancer detection\cancer\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pillow, opencv-python, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.0.5 cycler-0.11.0 fonttools-4.37.4 kiwisolver-1.4.4 matplotlib-3.6.1 opencv-python-4.6.0.66 pillow-9.2.0
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the 'D:\YouTube\12-10-2022 - Cancer Detection\cancer\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import cv2
import json
from matplotlib import pyplot as plt
import numpy as np

# %%
prediction = json.loads(response.text)

# %%
yhat = np.array(json.loads(prediction['prediction']))
yhat = np.squeeze(np.where(yhat > 0.3, 1.0, 0.0))

# %%
x = cv2.imread('testimg.jpg')

# %%
fig, ax = plt.subplots(1,7, figsize=(20,10))
ax[0].imshow(x) 
for i in range(6):
    ax[i+1].imshow(yhat[:,:,i])
